# %% [markdown]
# Look at the diagonals

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
root = Path("../input")

# %%
train = pd.read_csv(root.joinpath("train.csv"))
test = pd.read_csv(root.joinpath("test.csv"))

# %%
target = train.target.values
del train['target']
train['target'] = target
test['target'] = -1

# %%
x = train['var_0'].value_counts()
x = x[x==1].reset_index(drop=False)
x.head()
# Out:
#      index  var_0
# 0  15.0634      1
# 1   9.0488      1
# 2  14.1188      1
# 3   4.8706      1
# 4  13.5332      1

# %%
candidates = []
for c in train.columns[1:-1]:
    if(train[train[c] == x['index'][0]].shape[0]==1):
        candidates.append(c)
indexes = []
for c in candidates:
    indexes.append(train[train[c] == x['index'][0]].index.values[0])
y = train.iloc[indexes][candidates]
y.head(y.shape[0])
# Out:
#           var_0    var_2    var_7   ...     var_183  var_184  var_190
# 184970  15.0634  10.8783  13.6450   ...     12.9973   5.0530   3.8441
# 78727    9.4466  15.0634  13.5321   ...     14.3084  -0.9045  -2.2448
# 194669  15.1342   5.3645  15.0634   ...      3.9280  22.6449   1.9477
# 182952  14.4616   9.8854  21.2056   ...      6.9289  16.7688   3.1207
# 112906  10.1721   8.8605  11.9857   ...      6.5827   0.0215   0.8260
# 129443   6.2064  10.9044  21.9549   ...      3.5634   1.8254   3.2333
# 42631    6.7886  14.5070  13.8280   ...     -1.9464  27.9934   4.7770
# 60591    8.0993   9.4519  16.8370   ...      7.6588  22.9047  -1.1111
# 21133   10.4579   8.7920  13.6653   ...     12.3921  13.6994  -3.8224
# 71758    9.4294  12.1928  14.7414   ...     13.9854   7.0208  -1.9681
# 101608   8.2508   8.9263  10.5742   ...      4.9965   7.3027   3.6281
# 28492    8.7479  11.7573  13.4458   ...      5.5438  12.4290   0.3936
# 106482   8.9685   8.2032  11.3339   ...      2.4509  28.8450  -0.8935
# 117270  17.1738   8.4117  14.5904   ...     11.1731  -9.1069   0.6332
# 113441  11.1625   9.2353  13.3979   ...     11.7836   1.0622   3.9769
# 16921   15.0946   8.8857  18.0021   ...      7.9605   8.4786   7.1025
# 138011   6.7521   7.0615  13.4102   ...     12.2503  25.3494   6.3229
# 111552  10.8541  11.4585  13.9048   ...     -2.5234   3.4040   0.1298
# 143917  10.5230   9.2452  11.1805   ...      9.7473  21.7225   4.6581
# 53425   10.3275   9.2093  15.9224   ...      8.3497  15.9283  -2.3416
# 91053   12.8889   9.9177  10.4829   ...      8.2096  11.8728   6.1166
# 33461    7.7994  15.6661  23.4756   ...      4.8577   6.2817   2.0684
# 18940    7.0092  11.1546  15.2649   ...     11.3371  12.0146   5.4315
# 10868   16.6322  11.3443  17.3062   ...      2.0428   3.6010   1.1370
# 40658   14.9738  10.5595  16.0923   ...      4.6229   5.5927  -0.7080
# 194720   7.1369  11.9106  12.8842   ...      3.4525  -0.6945   5.1037
# 180562   3.4678  10.7638  22.9413   ...      6.3452  -3.9351   2.6729
# 120865   8.0789   8.4486  18.8711   ...     12.8723  14.9155  -2.9381
# 110591  15.8190  13.8247  19.5376   ...     15.0634  19.5428   8.4891
# 39888   11.4414   7.0219  22.3357   ...      8.6118  15.0634   6.7802
# 69325    9.6445   9.3684  13.6854   ...      7.2733   2.1708  15.0634
#
# [31 rows x 31 columns]

# %%
candidates = []
for c in test.columns[1:-1]:
    if(test[test[c] == x['index'][0]].shape[0]==1):
        candidates.append(c)
indexes = []
for c in candidates:
    indexes.append(test[test[c] == x['index'][0]].index.values[0])
y = test.iloc[indexes][candidates]
y.head(y.shape[0])
# Out:
#          var_19   var_33   var_46   var_49   var_60   var_85  var_156
# 16564   15.0634  11.9971   6.2313  19.5488  16.4410  11.4290  12.3884
# 23640   17.6326  15.0634   6.9950  10.8347   6.2490  19.8874  13.0997
# 50955   23.1218  19.4495  15.0634  13.7630  18.1776  18.5998  11.7670
# 79132   21.3946  10.6921  11.9370  15.0634   9.2618  10.5847  12.0392
# 159148   5.0597  12.8501   7.0026  13.5542  15.0634  19.7306  14.0383
# 167530  31.3493  20.0486  13.0577   7.2722  11.0419  15.0634  13.6233
# 100597  14.5002  10.9273  17.1605  18.2595   9.7164  11.9246  15.0634

# %%
candidates = []
for c in train.columns[1:-1]:
    if(train[train[c] == x['index'][1]].shape[0]==1):
        candidates.append(c)
indexes = []
for c in candidates:
    indexes.append(train[train[c] == x['index'][1]].index.values[0])
y = train.iloc[indexes][candidates]
y.head(y.shape[0])
# Out:
#           var_0   var_13   var_18   ...     var_182  var_188  var_193
# 182650   9.0488  13.3262   6.1601   ...    -17.0568  21.4463  -0.7605
# 110617   9.1161   9.0488  24.0580   ...    -14.7795  12.6363   2.1113
# 95500    9.0570   3.5552   9.0488   ...     -2.1698  17.0743  -1.0876
# 171065  10.4610   6.6574  10.0643   ...     17.8909  16.3263   7.6712
# 126513  11.6237   9.2175  16.4752   ...     11.7810  16.8432   0.0735
# 117267   8.1523  18.0902   5.2748   ...      1.4992  11.5347   5.9085
# 89834   12.7385   4.9197   6.7484   ...     -3.6913  13.9411  -2.4940
# 174971  14.5427   2.8055  23.0911   ...    -10.5677  10.6553   7.5995
# 110880  12.9282   3.7314  17.6497   ...     13.1309  13.9929   4.7135
# 34706   13.6050   9.5361  32.1078   ...    -18.6016  13.1231   7.3614
# 119063  12.5871   4.9004   4.1604   ...     -7.6211  12.8583   0.7975
# 32748   17.1067   3.6924   3.3421   ...     -5.2052  19.2541   2.0038
# 22892    4.7732  14.5486  23.6742   ...     10.5101  20.8067   6.9186
# 54667   10.3015  13.4246  13.0705   ...      5.5464   7.3537  -0.3893
# 20082    8.6238  11.5021   8.4251   ...      4.9087  15.7796  -1.9025
# 23089   10.5598   2.7009   7.2154   ...     -1.3944   7.6344   3.3155
# 47789    9.3138   4.9148  17.3831   ...      3.2239   8.0347  -1.4818
# 175594  13.7938   8.9974  22.9816   ...      5.6428  14.6104   4.0896
# 153429  10.0081  15.0320   8.5891   ...      2.4321  21.1483   4.2603
# 58739    7.4497   2.3437  23.1732   ...     -8.8453  14.5658   5.7990
# 174078  12.7037   4.3636  27.3786   ...     13.2526  19.8372   4.3010
# 173519  12.8248   8.1721  22.9643   ...      1.3802  18.7925   2.2795
# 162746  11.0502   8.3678  22.6918   ...      7.3966  14.5184   3.0439
# 172497  11.2486   7.9426  17.5661   ...      7.8549  20.0670  -7.1520
# 34307    8.2401  14.3692  24.6117   ...     11.3467  16.2912   3.2385
# 31790   15.1630  16.2529   8.7775   ...     -7.7453  14.5939   3.7670
# 32979    5.7392  15.3101  23.6774   ...      5.2643  14.7654   9.2600
# 167487  10.1175  10.0952  10.4209   ...     15.3644  20.0010   0.3895
# 150593  14.2491  11.2028  26.6120   ...     -4.8471  14.3383  -1.8647
# 17723    5.3879   9.9647  24.8684   ...     -5.1521  15.8709   8.0399
# 6807    13.0894   0.1142  15.7398   ...     -7.3954  14.7116  -0.6879
# 131273   8.9468   8.7866   0.2284   ...      9.0488   9.7254  -0.5243
# 154713   8.8446  10.1530   9.4554   ...     13.3306   9.0488   3.0330
# 76889   13.2181   7.5020  17.4734   ...      9.0314  15.9590   9.0488
#
# [34 rows x 34 columns]

# %%
candidates = []
for c in test.columns[1:-1]:
    if(test[test[c] == x['index'][1]].shape[0]==1):
        candidates.append(c)
indexes = []
for c in candidates:
    indexes.append(test[test[c] == x['index'][1]].index.values[0])
y = test.iloc[indexes][candidates]
y.head(y.shape[0])
# Out:
#           var_4   var_42   var_60   ...     var_151  var_184  var_191
# 55762    9.0488  10.9316  14.2509   ...      5.0277  18.3754   6.9675
# 21455   11.0651   9.0488  10.0103   ...     14.3068  25.7119  10.0576
# 178955  11.3628  10.5797   9.0488   ...     12.6106   8.3370  11.6565
# 179254  10.7799   9.8002  11.0949   ...     14.8716  20.1285   4.6130
# 26524   14.2498  11.8819  17.5038   ...     16.8909   4.5514   8.7962
# 167041  13.4130  11.2909  12.2783   ...     12.4700   9.4282   3.5124
# 97231   11.1718  11.1277  18.7490   ...      7.9525   1.2341  11.7414
# 86884   13.1320  11.3327   7.4184   ...      9.0488  28.8820   6.9455
# 186113  12.7350  11.2940  24.0312   ...      7.0168   9.0488   3.5209
# 72370   10.2712  10.7294  11.9645   ...     11.0491  18.7816   9.0488
#
# [10 rows x 10 columns]
